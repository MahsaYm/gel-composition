# %% [markdown]
# # Uniformity

# %%
import sys
import os

# Add the parent directory to Python path to enable imports
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import pandas
from analyzer.hyperparameter_analysis import run_all_nested_training
from experiment_configs.dataset import DatasetConfig, FORMULATION_COLUMNS, PRINTING_CONDITION_COLUMNS

with pandas.option_context('display.max_colwidth', None):

    display(run_all_nested_training(DatasetConfig(
        dataset_types=['Optimization', 'Mahsa'],
        target_column='Uniformity',
        input_columns=FORMULATION_COLUMNS + PRINTING_CONDITION_COLUMNS,
    )))
# Out:
#                    model_name  \
# 0         KNeighborsRegressor
# 1    GaussianProcessRegressor
# 2                MLPRegressor
# 3   GradientBoostingRegressor
# 4       RandomForestRegressor
# 5       RandomForestRegressor
# 6                  ElasticNet
# 7                  ElasticNet
# 8                       Lasso
# 9                  ElasticNet
# 10                      Ridge
# 11                      Ridge
# 12               MLPRegressor
# 13                        SVR
# 14                        SVR
# 15                        SVR
# 16      DecisionTreeRegressor
# 17      DecisionTreeRegressor
# 18      DecisionTreeRegressor
# 19        KNeighborsRegressor
# 20                      Lasso
# 21                 ElasticNet
# 22                      Ridge
# 23  GradientBoostingRegressor
# 24      RandomForestRegressor
# 25      DecisionTreeRegressor
# 26   GaussianProcessRegressor
# 27               MLPRegressor
# 28                        SVR
#
#                                                                                                                     model_params  \
# 0                                                                              {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 1                                                                     {'alpha': 1e-10, 'kernel': Matern(length_scale=1, nu=1.5)}
# 2              {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.1, 'solver': 'adam'}
# 3                                                   {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.8}
# 4                                                                     {'bootstrap': True, 'max_depth': None, 'n_estimators': 50}
# 5                                                                       {'bootstrap': True, 'max_depth': 4, 'n_estimators': 100}
# 6                                                    {'alpha': 1, 'fit_intercept': True, 'l1_ratio': 0.2, 'selection': 'cyclic'}
# 7                                                   {'alpha': 1, 'fit_intercept': False, 'l1_ratio': 0.2, 'selection': 'cyclic'}
# 8                                                   {'alpha': 1, 'fit_intercept': True, 'max_iter': 1000, 'selection': 'cyclic'}
# 9                                                    {'alpha': 1, 'fit_intercept': True, 'l1_ratio': 0.5, 'selection': 'cyclic'}
# 10                                                                                     {'alpha': 100000, 'fit_intercept': False}
# 11                                                                                      {'alpha': 100000, 'fit_intercept': True}
# 12          {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100), 'learning_rate_init': 0.1, 'solver': 'adam'}
# 13                                                 {'C': 0.001, 'coef0': 1, 'epsilon': 0.5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 14                                                    {'C': 10, 'coef0': 1, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 15                                                 {'C': 0.001, 'coef0': 1, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 16                                                              {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 17                                                           {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 18                                                           {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 20}
# 19                                                                              {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 20                                             {'alpha': 0.001, 'fit_intercept': False, 'max_iter': 5000, 'selection': 'cyclic'}
# 21                                              {'alpha': 0.001, 'fit_intercept': False, 'l1_ratio': 0.1, 'selection': 'cyclic'}
# 22                                                                                       {'alpha': 0.001, 'fit_intercept': True}
# 23                                                {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 300, 'subsample': 1.0}
# 24                                                                     {'bootstrap': False, 'max_depth': 10, 'n_estimators': 10}
# 25                                                              {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 26                                                                                              {'alpha': 1e-10, 'kernel': 1**2}
# 27  {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.001, 'solver': 'lbfgs'}
# 28                                                     {'C': 100, 'coef0': 0.1, 'epsilon': 0.5, 'gamma': 1, 'kernel': 'sigmoid'}
#
#               r2         mae        mape            mse        rmse  \
# 0       0.162093    1.622686    0.388171       4.669059    2.160800
# 1       0.141377    1.707160    0.420442       4.784495    2.187349
# 2       0.068495    1.884466    0.479595       5.190616    2.278292
# 3       0.041829    1.722574    0.442091       5.339207    2.310672
# 4       0.032957    1.751104    0.438772       5.388645    2.321345
# 5      -0.017836    1.716709    0.429219       5.671673    2.381527
# 6      -0.057654    1.922085    0.480924       5.893552    2.427664
# 7      -0.057654    1.922085    0.480924       5.893552    2.427664
# 8      -0.059689    1.921890    0.481244       5.904890    2.429998
# 9      -0.059689    1.921890    0.481244       5.904890    2.429998
# 10     -0.059793    1.921985    0.481259       5.905469    2.430117
# 11     -0.059793    1.921985    0.481259       5.905469    2.430117
# 12     -0.076107    1.743990    0.461322       5.996379    2.448751
# 13     -0.138503    1.840250    0.422998       6.344069    2.518744
# 14     -0.148601    1.657487    0.329722       6.400338    2.529889
# 15     -0.150768    1.667194    0.329449       6.412412    2.532274
# 16     -0.350403    1.967379    0.470657       7.524834    2.743143
# 17     -0.350403    1.967379    0.470657       7.524834    2.743143
# 18     -0.366977    1.917093    0.454870       7.617191    2.759926
# 19     -0.487951    1.992516    0.491526       8.291290    2.879460
# 20     -0.532222    2.298962    0.576774       8.537979    2.921982
# 21     -0.542225    2.308633    0.580662       8.593723    2.931505
# 22     -0.621367    2.366455    0.601714       9.034726    3.005782
# 23     -1.077912    2.539162    0.680369      11.578725    3.402753
# 24     -1.124750    2.526132    0.681836      11.839718    3.440889
# 25     -1.382137    2.684687    0.740746      13.273956    3.643344
# 26     -1.569293    2.871643    0.702914      14.316838    3.783760
# 27     -8.923191    3.801411    1.025981      55.294879    7.436053
# 28 -87299.921767  586.841553  168.515538  486465.871238  697.471054
#
#     explained_var
# 0        0.195231
# 1        0.151677
# 2        0.090191
# 3        0.042439
# 4        0.033420
# 5       -0.016828
# 6       -0.057654
# 7       -0.057654
# 8       -0.059689
# 9       -0.059689
# 10      -0.059793
# 11      -0.059793
# 12      -0.069303
# 13      -0.108513
# 14      -0.011768
# 15      -0.006789
# 16      -0.329077
# 17      -0.329077
# 18      -0.347271
# 19      -0.480335
# 20      -0.532046
# 21      -0.541919
# 22      -0.620042
# 23      -1.054897
# 24      -1.089302
# 25      -1.319097
# 26      -1.432540
# 27      -8.621376
# 28  -84972.057521

# %% [markdown]
# # Disintegration

# %%
import sys
import os

# Add the parent directory to Python path to enable imports
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import pandas
from analyzer.hyperparameter_analysis import run_all_nested_training
from experiment_configs.dataset import DatasetConfig, FORMULATION_COLUMNS, PRINTING_CONDITION_COLUMNS

with pandas.option_context('display.max_colwidth', None):

    display(run_all_nested_training(DatasetConfig(
        dataset_types=['Optimization', 'Mahsa'],
        target_column='Disintegration',
        input_columns=FORMULATION_COLUMNS + PRINTING_CONDITION_COLUMNS,
    )))
# Out:
#                    model_name  \
# 0   GradientBoostingRegressor
# 1                MLPRegressor
# 2       DecisionTreeRegressor
# 3       RandomForestRegressor
# 4                MLPRegressor
# 5                         SVR
# 6       RandomForestRegressor
# 7   GradientBoostingRegressor
# 8                         SVR
# 9                       Ridge
# 10   GaussianProcessRegressor
# 11                 ElasticNet
# 12                      Lasso
# 13                      Lasso
# 14                      Ridge
# 15        KNeighborsRegressor
# 16        KNeighborsRegressor
# 17      DecisionTreeRegressor
# 18  GradientBoostingRegressor
# 19                      Ridge
# 20                 ElasticNet
# 21                      Lasso
# 22      RandomForestRegressor
# 23               MLPRegressor
# 24   GaussianProcessRegressor
# 25                        SVR
#
#                                                                                                                   model_params  \
# 0                                                {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 50, 'subsample': 1.0}
# 1   {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100), 'learning_rate_init': 0.01, 'solver': 'lbfgs'}
# 2                                                            {'max_depth': 100, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 3                                                                  {'bootstrap': False, 'max_depth': None, 'n_estimators': 20}
# 4          {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.001, 'solver': 'adam'}
# 5                                                      {'C': 1, 'coef0': 1, 'epsilon': 0.5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 6                                                                   {'bootstrap': True, 'max_depth': None, 'n_estimators': 10}
# 7                                                {'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 300, 'subsample': 0.8}
# 8                                                    {'C': 10, 'coef0': 1, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 9                                                                                          {'alpha': 1, 'fit_intercept': True}
# 10                                                                             {'alpha': 1.0, 'kernel': DotProduct(sigma_0=1)}
# 11                                               {'alpha': 0.1, 'fit_intercept': True, 'l1_ratio': 0.1, 'selection': 'cyclic'}
# 12                                             {'alpha': 0.01, 'fit_intercept': True, 'max_iter': 5000, 'selection': 'random'}
# 13                                              {'alpha': 0.1, 'fit_intercept': True, 'max_iter': 5000, 'selection': 'random'}
# 14                                                                                        {'alpha': 10, 'fit_intercept': True}
# 15                                                                           {'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 16                                                                            {'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 17                                                           {'max_depth': 50, 'min_samples_leaf': 8, 'min_samples_split': 10}
# 18                                              {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 1.0}
# 19                                                                                    {'alpha': 100000, 'fit_intercept': True}
# 20                                                 {'alpha': 1, 'fit_intercept': True, 'l1_ratio': 0.9, 'selection': 'cyclic'}
# 21                                                {'alpha': 1, 'fit_intercept': True, 'max_iter': 1000, 'selection': 'cyclic'}
# 22                                                                   {'bootstrap': False, 'max_depth': 1, 'n_estimators': 500}
# 23         {'activation': 'relu', 'alpha': 0.1, 'hidden_layer_sizes': (100, 100), 'learning_rate_init': 0.1, 'solver': 'adam'}
# 24                                                                                            {'alpha': 1e-10, 'kernel': 1**2}
# 25                                                     {'C': 100, 'coef0': 1, 'epsilon': 0.5, 'gamma': 1, 'kernel': 'sigmoid'}
#
#                r2           mae        mape           mse          rmse  \
# 0        0.746037     49.129297    0.273018  5.638629e+03     75.090803
# 1        0.745066     61.272155    0.339549  5.660181e+03     75.234176
# 2        0.720020     53.231481    0.298601  6.216285e+03     78.843424
# 3        0.697709     55.402315    0.306879  6.711637e+03     81.924581
# 4        0.694651     56.434378    0.287323  6.779534e+03     82.337929
# 5        0.683049     63.954019    0.420870  7.037137e+03     83.887648
# 6        0.673227     49.928704    0.295017  7.255210e+03     85.177522
# 7        0.672500     48.488983    0.246698  7.271338e+03     85.272140
# 8        0.660481     61.588556    0.344562  7.538199e+03     86.822801
# 9        0.655639     67.131246    0.384642  7.645701e+03     87.439699
# 10       0.655639     67.131246    0.384642  7.645701e+03     87.439699
# 11       0.653141     63.509882    0.357213  7.701173e+03     87.756327
# 12       0.650404     67.693069    0.390860  7.761942e+03     88.101883
# 13       0.633960     64.370016    0.384387  8.127029e+03     90.150035
# 14       0.631790     64.517435    0.376100  8.175204e+03     90.416834
# 15       0.518269     71.150008    0.394057  1.069566e+04    103.419826
# 16       0.393062     86.762963    0.505992  1.347558e+04    116.084382
# 17       0.392208     84.951903    0.445026  1.349455e+04    116.166066
# 18      -0.046171    118.753289    0.705250  2.322769e+04    152.406331
# 19      -0.056984    119.587543    0.709771  2.346777e+04    153.191954
# 20      -0.057959    119.649206    0.710120  2.348942e+04    153.262588
# 21      -0.057959    119.649206    0.710120  2.348942e+04    153.262588
# 22      -0.072859    131.573582    0.723815  2.382023e+04    154.338035
# 23      -0.156374    121.432005    0.875773  2.567449e+04    160.232613
# 24      -0.171075    126.167063    0.730377  2.600089e+04    161.247913
# 25 -105545.115738  39847.078362  240.208791  2.343396e+09  48408.633774
#
#     explained_var
# 0        0.746830
# 1        0.746583
# 2        0.721847
# 3        0.697951
# 4        0.694678
# 5        0.684132
# 6        0.673258
# 7        0.676372
# 8        0.666895
# 9        0.656018
# 10       0.656018
# 11       0.653262
# 12       0.650860
# 13       0.634105
# 14       0.631849
# 15       0.519251
# 16       0.394709
# 17       0.392500
# 18      -0.046171
# 19      -0.056984
# 20      -0.057959
# 21      -0.057959
# 22      -0.070078
# 23      -0.150229
# 24      -0.169552
# 25 -101457.213182

# %% [markdown]
# # Tanδ

# %%
import sys
import os

# Add the parent directory to Python path to enable imports
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import pandas
from analyzer.hyperparameter_analysis import run_all_nested_training
from experiment_configs.dataset import DatasetConfig, FORMULATION_COLUMNS, PRINTING_CONDITION_COLUMNS

with pandas.option_context('display.max_colwidth', None):

    display(run_all_nested_training(DatasetConfig(
        dataset_types=['Optimization', 'Mahsa'],
        target_column='Tanδ',
        input_columns=FORMULATION_COLUMNS + PRINTING_CONDITION_COLUMNS,
    )))
# Out:
#                    model_name  \
# 0                MLPRegressor
# 1                MLPRegressor
# 2       DecisionTreeRegressor
# 3                         SVR
# 4    GaussianProcessRegressor
# 5       RandomForestRegressor
# 6    GaussianProcessRegressor
# 7       RandomForestRegressor
# 8   GradientBoostingRegressor
# 9   GradientBoostingRegressor
# 10                      Lasso
# 11                 ElasticNet
# 12                      Ridge
# 13                      Ridge
# 14        KNeighborsRegressor
# 15      RandomForestRegressor
# 16        KNeighborsRegressor
# 17  GradientBoostingRegressor
# 18                      Ridge
# 19                      Lasso
# 20                 ElasticNet
# 21      DecisionTreeRegressor
# 22               MLPRegressor
# 23   GaussianProcessRegressor
# 24                        SVR
#
#                                                                                                              model_params  \
# 0      {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.1, 'solver': 'adam'}
# 1   {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.1, 'solver': 'lbfgs'}
# 2                                                        {'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 3                                              {'C': 100, 'coef0': 0, 'epsilon': 0.2, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 4                                                                         {'alpha': 1e-10, 'kernel': RBF(length_scale=1)}
# 5                                                             {'bootstrap': False, 'max_depth': None, 'n_estimators': 10}
# 6                                                              {'alpha': 1e-10, 'kernel': Matern(length_scale=1, nu=1.5)}
# 7                                                               {'bootstrap': False, 'max_depth': 10, 'n_estimators': 10}
# 8                                           {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'subsample': 0.8}
# 9                                           {'learning_rate': 0.2, 'max_depth': 10, 'n_estimators': 50, 'subsample': 1.0}
# 10                                       {'alpha': 0.01, 'fit_intercept': False, 'max_iter': 2000, 'selection': 'random'}
# 11                                        {'alpha': 0.01, 'fit_intercept': False, 'l1_ratio': 0.9, 'selection': 'random'}
# 12                                                                                   {'alpha': 1, 'fit_intercept': False}
# 13                                                                                    {'alpha': 1, 'fit_intercept': True}
# 14                                                                      {'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 15                                                               {'bootstrap': False, 'max_depth': 1, 'n_estimators': 50}
# 16                                                                       {'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 17                                         {'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 10, 'subsample': 0.8}
# 18                                                                              {'alpha': 100000, 'fit_intercept': False}
# 19                                          {'alpha': 1, 'fit_intercept': False, 'max_iter': 1000, 'selection': 'cyclic'}
# 20                                           {'alpha': 1, 'fit_intercept': False, 'l1_ratio': 0.9, 'selection': 'cyclic'}
# 21                                                    {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 22    {'activation': 'logistic', 'alpha': 0.1, 'hidden_layer_sizes': (100,), 'learning_rate_init': 0.1, 'solver': 'adam'}
# 23                                                                      {'alpha': 1e-10, 'kernel': DotProduct(sigma_0=1)}
# 24                                                {'C': 100, 'coef0': 1, 'epsilon': 0.5, 'gamma': 1, 'kernel': 'sigmoid'}
#
#               r2       mae       mape        mse      rmse  explained_var
# 0       0.866388  0.009093   0.060267   0.000179  0.013380       0.877015
# 1       0.839835  0.008562   0.050855   0.000215  0.014649       0.841572
# 2       0.776085  0.010000   0.057479   0.000300  0.017321       0.788740
# 3       0.733900  0.012803   0.079536   0.000357  0.018882       0.737392
# 4       0.732722  0.011772   0.075756   0.000358  0.018923       0.733445
# 5       0.727921  0.011588   0.067471   0.000365  0.019093       0.729287
# 6       0.710529  0.011134   0.068441   0.000388  0.019693       0.711165
# 7       0.701929  0.011000   0.063460   0.000399  0.019984       0.703812
# 8       0.697805  0.011941   0.070413   0.000405  0.020122       0.699898
# 9       0.689087  0.011169   0.065564   0.000417  0.020410       0.691062
# 10      0.666477  0.015022   0.096978   0.000447  0.021139       0.666961
# 11      0.665997  0.015078   0.097540   0.000447  0.021154       0.666409
# 12      0.654975  0.015461   0.100616   0.000462  0.021500       0.655729
# 13      0.654975  0.015461   0.100616   0.000462  0.021500       0.655729
# 14      0.574837  0.014961   0.092315   0.000570  0.023867       0.574958
# 15      0.366960  0.021006   0.133251   0.000848  0.029123       0.369852
# 16      0.334596  0.023137   0.147589   0.000892  0.029858       0.360422
# 17     -0.116554  0.029393   0.189500   0.001496  0.038678      -0.116554
# 18     -0.128238  0.029621   0.191056   0.001512  0.038879      -0.128238
# 19     -0.128906  0.029632   0.191134   0.001513  0.038891      -0.128906
# 20     -0.128906  0.029632   0.191134   0.001513  0.038891      -0.128906
# 21     -0.128906  0.029632   0.191134   0.001513  0.038891      -0.128906
# 22     -0.144458  0.035105   0.236211   0.001533  0.039158      -0.127142
# 23     -3.963647  0.036794   0.278662   0.006650  0.081549      -3.697601
# 24 -49120.113227  6.722934  48.346882  65.812094  8.112465  -43641.487947

# %% [markdown]
# # Recovery

# %%
import sys
import os

# Add the parent directory to Python path to enable imports
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import pandas
from analyzer.hyperparameter_analysis import run_all_nested_training
from experiment_configs.dataset import DatasetConfig, FORMULATION_COLUMNS, PRINTING_CONDITION_COLUMNS

with pandas.option_context('display.max_colwidth', None):

    display(run_all_nested_training(DatasetConfig(
        dataset_types=['Optimization', 'Mahsa'],
        target_column='Recovery',
        input_columns=FORMULATION_COLUMNS + PRINTING_CONDITION_COLUMNS,
    )))
# Out:
#                    model_name  \
# 0   GradientBoostingRegressor
# 1       DecisionTreeRegressor
# 2       RandomForestRegressor
# 3       RandomForestRegressor
# 4                MLPRegressor
# 5                MLPRegressor
# 6    GaussianProcessRegressor
# 7    GaussianProcessRegressor
# 8         KNeighborsRegressor
# 9                         SVR
# 10      RandomForestRegressor
# 11                      Ridge
# 12                      Ridge
# 13                 ElasticNet
# 14                 ElasticNet
# 15                      Lasso
# 16                      Lasso
# 17        KNeighborsRegressor
# 18  GradientBoostingRegressor
# 19                      Ridge
# 20                      Lasso
# 21                 ElasticNet
# 22      DecisionTreeRegressor
# 23               MLPRegressor
# 24   GaussianProcessRegressor
# 25                        SVR
#
#                                                                                                                 model_params  \
# 0                                              {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}
# 1                                                           {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 2                                                                  {'bootstrap': False, 'max_depth': 10, 'n_estimators': 10}
# 3                                                                   {'bootstrap': False, 'max_depth': 5, 'n_estimators': 20}
# 4     {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.01, 'solver': 'lbfgs'}
# 5       {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.1, 'solver': 'lbfgs'}
# 6                                                                  {'alpha': 0.01, 'kernel': Matern(length_scale=1, nu=1.5)}
# 7                                                                 {'alpha': 1e-10, 'kernel': Matern(length_scale=1, nu=1.5)}
# 8                                                                          {'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 9                                                 {'C': 100, 'coef0': 0, 'epsilon': 0.5, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 10                                                                   {'bootstrap': True, 'max_depth': 1, 'n_estimators': 10}
# 11                                                                                     {'alpha': 10, 'fit_intercept': False}
# 12                                                                                      {'alpha': 10, 'fit_intercept': True}
# 13                                             {'alpha': 0.1, 'fit_intercept': True, 'l1_ratio': 0.1, 'selection': 'random'}
# 14                                              {'alpha': 1, 'fit_intercept': False, 'l1_ratio': 0.1, 'selection': 'random'}
# 15                                           {'alpha': 0.01, 'fit_intercept': True, 'max_iter': 5000, 'selection': 'random'}
# 16                                           {'alpha': 0.1, 'fit_intercept': False, 'max_iter': 1000, 'selection': 'random'}
# 17                                                                          {'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 18                                           {'learning_rate': 0.001, 'max_depth': 10, 'n_estimators': 10, 'subsample': 0.8}
# 19                                                                                  {'alpha': 100000, 'fit_intercept': True}
# 20                                              {'alpha': 1, 'fit_intercept': True, 'max_iter': 1000, 'selection': 'cyclic'}
# 21                                               {'alpha': 1, 'fit_intercept': True, 'l1_ratio': 0.9, 'selection': 'cyclic'}
# 22                                                       {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 23  {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 100), 'learning_rate_init': 0.1, 'solver': 'adam'}
# 24                                                                         {'alpha': 1e-10, 'kernel': DotProduct(sigma_0=1)}
# 25                                                  {'C': 100, 'coef0': 1, 'epsilon': 0.01, 'gamma': 1, 'kernel': 'sigmoid'}
#
#               r2          mae       mape           mse         rmse  \
# 0       0.842218     2.332653   0.083365  1.024006e+01     3.200009
# 1       0.840952     2.464118   0.075473  1.032221e+01     3.212819
# 2       0.807246     2.706176   0.087265  1.250978e+01     3.536916
# 3       0.806225     2.627529   0.081488  1.257599e+01     3.546265
# 4       0.777504     2.673105   0.096028  1.443999e+01     3.799999
# 5       0.732263     2.401521   0.087387  1.737618e+01     4.168475
# 6       0.721548     2.830055   0.110528  1.807155e+01     4.251065
# 7       0.715527     2.685190   0.107506  1.846233e+01     4.296781
# 8       0.618700     3.042580   0.125142  2.474643e+01     4.974579
# 9       0.569639     4.284077   0.142314  2.793047e+01     5.284929
# 10      0.554752     3.958038   0.150261  2.889660e+01     5.375556
# 11      0.518150     4.445797   0.155874  3.127212e+01     5.592148
# 12      0.518150     4.445797   0.155874  3.127212e+01     5.592148
# 13      0.462164     4.758514   0.157221  3.490557e+01     5.908094
# 14      0.448461     4.619209   0.167250  3.579494e+01     5.982888
# 15      0.313069     5.187762   0.164998  4.458188e+01     6.676967
# 16      0.284266     5.183839   0.176703  4.645116e+01     6.815509
# 17     -0.019625     5.748235   0.216822  6.617375e+01     8.134725
# 18     -0.111802     7.050286   0.250500  7.215603e+01     8.494470
# 19     -0.128266     7.108652   0.252465  7.322454e+01     8.557134
# 20     -0.128906     7.111029   0.252541  7.326611e+01     8.559562
# 21     -0.128906     7.111029   0.252541  7.326611e+01     8.559562
# 22     -0.128906     7.111029   0.252541  7.326611e+01     8.559562
# 23     -0.587898     7.579245   0.287687  1.030547e+02    10.151588
# 24    -20.500176    13.820537   0.379893  1.395363e+03    37.354560
# 25 -61607.481234  1743.208530  49.320320  3.998395e+06  1999.598815
#
#     explained_var
# 0        0.843139
# 1        0.867776
# 2        0.809284
# 3        0.809452
# 4        0.781395
# 5        0.733083
# 6        0.725561
# 7        0.720610
# 8        0.661424
# 9        0.579081
# 10       0.567983
# 11       0.521509
# 12       0.521509
# 13       0.471235
# 14       0.450216
# 15       0.324479
# 16       0.299052
# 17      -0.015364
# 18      -0.111802
# 19      -0.128266
# 20      -0.128906
# 21      -0.128906
# 22      -0.128906
# 23      -0.424087
# 24     -19.616493
# 25  -58645.476500
